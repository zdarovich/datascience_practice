# %%
# %matplotlib inline
import pandas as pd
cars = pd.read_csv("imports-85.data")
cols = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 
        'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 
        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-rate', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
cars.columns = cols
cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# 5            1               158         audi       gas        std
# 6            1                 ?         audi       gas        std
# 7            1               158         audi       gas      turbo
# 8            0                 ?         audi       gas      turbo
# 9            2               192          bmw       gas        std
# 10           0               192          bmw       gas        std
# 11           0               188          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
import numpy as np

cars = cars.replace("?", np.nan)
continuous_values_cols = ['normalized-losses', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'bore', 'stroke', 'compression-rate', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
cars_num = cars
cars = cars[continuous_values_cols]
cars
# Out:
#     normalized-losses  wheel-base  length  width  height  curb-weight  bore  \
# 0                 NaN        88.6   168.8   64.1    48.8         2548  3.47
# 1                 NaN        94.5   171.2   65.5    52.4         2823  2.68
# 2                 164        99.8   176.6   66.2    54.3         2337  3.19
# 3                 164        99.4   176.6   66.4    54.3         2824  3.19
# 4                 NaN        99.8   177.3   66.3    53.1         2507  3.19
# 5                 158       105.8   192.7   71.4    55.7         2844  3.19
# 6                 NaN       105.8   192.7   71.4    55.7         2954  3.19
# 7                 158       105.8   192.7   71.4    55.9         3086  3.13
# 8                 NaN        99.5   178.2   67.9    52.0         3053  3.13
# 9                 192       101.2   176.8   64.8    54.3         2395  3.50
# 10                192       101.2   176.8   64.8    54.3         2395  3.50
# ...

# %%
cars = cars.dropna(subset=["price"])
cars.isnull().sum()
# Out:
# normalized-losses    36
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# bore                  4
# stroke                4
# compression-rate      0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
cars = cars.astype(float)
cars.dtypes
cars = cars.fillna(cars.mean())
cars.isnull().sum()
cars_price = cars["price"]
cars = (cars - cars.min()) / (cars.max() - cars.min())
cars["price"] = cars_price
cars
# Out:
#      normalized-losses  wheel-base    length     width    height  curb-weight  \
# 0             0.298429    0.058309  0.413433  0.324786  0.083333     0.411171
# 1             0.298429    0.230321  0.449254  0.444444  0.383333     0.517843
# 2             0.518325    0.384840  0.529851  0.504274  0.541667     0.329325
# 3             0.518325    0.373178  0.529851  0.521368  0.541667     0.518231
# 4             0.298429    0.384840  0.540299  0.512821  0.441667     0.395268
# 5             0.486911    0.559767  0.770149  0.948718  0.658333     0.525989
# 6             0.298429    0.559767  0.770149  0.948718  0.658333     0.568658
# 7             0.486911    0.559767  0.770149  0.948718  0.675000     0.619860
# 9             0.664921    0.425656  0.532836  0.384615  0.541667     0.351823
# 10            0.664921    0.425656  0.532836  0.384615  0.541667     0.351823
# 11            0.643979    0.425656  0.532836  0.384615  0.541667     0.474011
# ...

# %%
# Univariate Model
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

def knn_train_test(train_col, target_col, df):
    knn = KNeighborsRegressor()
    np.random.seed(1)
        
    # Randomize order of rows in data frame.
    shuffled_index = np.random.permutation(df.index)
    rand_df = df.reindex(shuffled_index)

    # Divide number of rows in half and round.
    last_train_row = int(len(rand_df) / 2)
    
    # Select the first half and set as training set.
    # Select the second half and set as test set.
    train_df = rand_df.iloc[0:last_train_row]
    test_df = rand_df.iloc[last_train_row:]
    
    # Fit a KNN model using default k value.
    knn.fit(train_df[[train_col]], train_df[target_col])
    
    # Make predictions using model.
    predicted_labels = knn.predict(test_df[[train_col]])

    # Calculate and return RMSE.
    mse = mean_squared_error(test_df[target_col], predicted_labels)
    rmse = np.sqrt(mse)
    return rmse

rmse_results_col = {}
train_cols = cars.columns.drop('price')

# For each column (minus `price`), train a model, return RMSE value
# and add to the dictionary `rmse_results`.
for col in train_cols:
    rmse_val = knn_train_test(col, 'price', cars)
    rmse_results_col[col] = rmse_val

plt.bar(range(len(rmse_results_col)), list(rmse_results_col.values()), align='center')
plt.xticks(range(len(rmse_results_col)), list(rmse_results_col.keys()), rotation = 90)
plt.show()

# %%
# K-Neighbors Model

def knn_train_test(train_col, target_col, df, k):
    knn = KNeighborsRegressor(n_neighbors=k)
    np.random.seed(1)
        
    # Randomize order of rows in data frame.
    shuffled_index = np.random.permutation(df.index)
    rand_df = df.reindex(shuffled_index)

    # Divide number of rows in half and round.
    last_train_row = int(len(rand_df) / 2)
    
    # Select the first half and set as training set.
    # Select the second half and set as test set.
    train_df = rand_df.iloc[0:last_train_row]
    test_df = rand_df.iloc[last_train_row:]
    
    # Fit a KNN model using default k value.
    knn.fit(train_df[[train_col]], train_df[target_col])
    
    # Make predictions using model.
    predicted_labels = knn.predict(test_df[[train_col]])

    # Calculate and return RMSE.
    mse = mean_squared_error(test_df[target_col], predicted_labels)
    rmse = np.sqrt(mse)
    return rmse

rmse_results = {}
train_cols = cars.columns.drop('price')

for col in train_cols:
    rmse_results_k = {}
    for k in range(1, 10):
        rmse_val = knn_train_test(col, 'price', cars, k)
        rmse_results_k[k] = rmse_val
    rmse_results[col] = rmse_results_k
for title, data_rmse in rmse_results.items():
    x = list(data_rmse.keys())
    y = list(data_rmse.values())
    plt.plot(x,y)
plt.show()

# %%
import numpy as nm
avg_rmse_results = {}
for col, results in rmse_results.items():
    avg_rmse_results[col] = nm.mean(list(results.values()))
series = pd.Series(avg_rmse_results)
series = series.sort_values()
series
# Out:
# curb-weight          3678.490589
# city-mpg             3733.474331
# highway-mpg          3761.707025
# width                3977.654125
# horsepower           4429.312840
# wheel-base           5326.422943
# length               5488.711478
# bore                 6222.429471
# compression-rate     7016.613202
# peak-rpm             7075.526978
# normalized-losses    7586.689285
# stroke               7709.480803
# height               7884.314266
# dtype: float64

# %%
#Multivariate model
def knn_train_test(train_col, target_col, df):
    knn = KNeighborsRegressor()
    np.random.seed(1)
        
    # Randomize order of rows in data frame.
    shuffled_index = np.random.permutation(df.index)
    rand_df = df.reindex(shuffled_index)

    # Divide number of rows in half and round.
    last_train_row = int(len(rand_df) / 2)
    
    # Select the first half and set as training set.
    # Select the second half and set as test set.
    train_df = rand_df.iloc[0:last_train_row]
    test_df = rand_df.iloc[last_train_row:]
    
    # Fit a KNN model using default k value.
    knn.fit(train_df[train_col], train_df[target_col])
    
    # Make predictions using model.
    predicted_labels = knn.predict(test_df[train_col])

    # Calculate and return RMSE.
    mse = mean_squared_error(test_df[target_col], predicted_labels)
    rmse = np.sqrt(mse)
    return rmse

rmse_results_best = {}
best_features = series.axes[0].tolist()
for feature_count in range(2,6):
    rmse = knn_train_test(best_features[:feature_count], "price", cars)
    rmse_results_best[feature_count] = rmse


x = list(rmse_results_best.keys())
y = list(rmse_results_best.values())
plt.plot(x,y)
plt.show()

rmse_results_best
# Out:
# {2: 3099.5755852696998,
#  3: 2959.1731912816458,
#  4: 3048.2253868767643,
#  5: 2692.4443467600217}

# %%
#Optimizing model
def knn_train_test(train_col, target_col, df):
    
    np.random.seed(1)
        
    # Randomize order of rows in data frame.
    shuffled_index = np.random.permutation(df.index)
    rand_df = df.reindex(shuffled_index)

    # Divide number of rows in half and round.
    last_train_row = int(len(rand_df) / 2)
    
    # Select the first half and set as training set.
    # Select the second half and set as test set.
    train_df = rand_df.iloc[0:last_train_row]
    test_df = rand_df.iloc[last_train_row:]
    
    rmses_values = {}
    for k in range(1,26):
        knn = KNeighborsRegressor(n_neighbors=k)
        # Fit a KNN model using default k value.
        knn.fit(train_df[train_col], train_df[target_col])
    
        # Make predictions using model.
        predicted_labels = knn.predict(test_df[train_col])

        # Calculate and return RMSE.
        mse = mean_squared_error(test_df[target_col], predicted_labels)
        rmse = np.sqrt(mse)
        rmses_values[k] = rmse
    return rmses_values

rmse_results_best = {}
best_features = series.axes[0].tolist()
for feature_count in range(3,6):
    rmse = knn_train_test(best_features[:feature_count], "price", cars)
    rmse_results_best[feature_count] = rmse
rmse_results_best

for k,v in rmse_results_best.items():
    x = list(v.keys())
    y = list(v.values())
    plt.plot(x,y)
    plt.xlabel("k_neighbors")
    plt.ylabel("RMSE")
plt.legend(list(rmse_results_best.keys()))
plt.show()

# %%
#Optimizing model with k-fold cross validation
from sklearn.cross_validation import cross_val_score,cross_val_predict
from sklearn.model_selection import KFold

train_cols = cars.columns.drop('price')
num_folds = [3, 5, 7, 9, 10, 11, 13, 15, 17, 19, 21, 23]
avg_rmses_fold = {}
for fold in num_folds:
    kf = KFold(fold, shuffle=True, random_state=1)
    model = KNeighborsRegressor()
    mses = cross_val_score(model, cars[train_cols], cars["price"], scoring="neg_mean_squared_error", cv=kf.split(cars))
    rmses = np.sqrt(np.absolute(mses))
    avg_rmse = np.mean(rmses)
    std_rmse = np.std(rmses)
    avg_rmses_fold[fold] = avg_rmse
    print(str(fold), "folds: ", "avg RMSE: ", str(avg_rmse), "std RMSE: ", str(std_rmse))
    
x = list(avg_rmses_fold.keys())
y = list(avg_rmses_fold.values())
plt.plot(x,y)
plt.xlabel("n_fold of cross validation")

plt.show()
# Out:
# 3 folds:  avg RMSE:  3703.6407987 std RMSE:  545.983060695
# 5 folds:  avg RMSE:  3403.90910189 std RMSE:  1184.7518284
# 7 folds:  avg RMSE:  3247.82361648 std RMSE:  1156.01178149
# 9 folds:  avg RMSE:  3311.94672554 std RMSE:  956.613139799
# 10 folds:  avg RMSE:  3248.12849011 std RMSE:  1593.18584833
# 11 folds:  avg RMSE:  3258.94136122 std RMSE:  1518.31612233
# 13 folds:  avg RMSE:  3283.51892183 std RMSE:  1368.80274837
# 15 folds:  avg RMSE:  3238.10711234 std RMSE:  1567.38793307
# 17 folds:  avg RMSE:  3313.09805903 std RMSE:  1470.19668236
# 19 folds:  avg RMSE:  3148.35125829 std RMSE:  1649.92410795
# 21 folds:  avg RMSE:  3124.76678706 std RMSE:  1552.43140366
# 23 folds:  avg RMSE:  3248.9440832 std RMSE:  1571.93047413
